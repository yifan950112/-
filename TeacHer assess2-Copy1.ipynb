# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
Data = pd.read_excel('/home/yifan/Desktop/学校版调考分析报告-武汉市第四中学.xlsx')

# %%
 #   分析各班级语文成绩
df_chinese = Data[["Unnamed: 0","Unnamed: 1","Unnamed: 2","Unnamed: 3","学科潜能原始分"]]

# %%
df_chinese
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 学科潜能原始分
# 0           考号         学校         班级       学生姓名    语文成绩
# 1    042020722    武汉市第四中学          2        胡淑祺   120.0
# 2    042020703    武汉市第四中学          2        李长坤   117.0
# 3    042020707    武汉市第四中学          2        刘大福   119.0
# 4    042010208    武汉市第四中学          6        李佳怡   128.0
# ..         ...        ...        ...        ...     ...
# 493  042021321    武汉市第四中学          9        何景轩    69.0
# 494  042021232    武汉市第四中学          4        曾治钧    79.0
# 495  042021313    武汉市第四中学          9         尹琳    82.0
# 496  042021325    武汉市第四中学          9        熊宇豪    53.0
# 497  042021040    武汉市第四中学          2        段茗馨    63.0
#
# [498 rows x 5 columns]

# %%
 ## 替换列索引
df_chinese1 = df_chinese.set_axis(df_chinese.iloc[0],axis = 1, inplace = False)

# %%
df_chinese1.columns.name = None

# %%
df_chinese1
# Out:
#             考号       学校  班级  学生姓名   语文成绩
# 0           考号       学校  班级  学生姓名   语文成绩
# 1    042020722  武汉市第四中学   2   胡淑祺  120.0
# 2    042020703  武汉市第四中学   2   李长坤  117.0
# 3    042020707  武汉市第四中学   2   刘大福  119.0
# 4    042010208  武汉市第四中学   6   李佳怡  128.0
# ..         ...      ...  ..   ...    ...
# 493  042021321  武汉市第四中学   9   何景轩   69.0
# 494  042021232  武汉市第四中学   4   曾治钧   79.0
# 495  042021313  武汉市第四中学   9    尹琳   82.0
# 496  042021325  武汉市第四中学   9   熊宇豪   53.0
# 497  042021040  武汉市第四中学   2   段茗馨   63.0
#
# [498 rows x 5 columns]

# %%
## 删除重复列
df = df_chinese1.drop(index = 0)

# %%
df
# Out:
#             考号       学校 班级 学生姓名   语文成绩
# 1    042020722  武汉市第四中学  2  胡淑祺  120.0
# 2    042020703  武汉市第四中学  2  李长坤  117.0
# 3    042020707  武汉市第四中学  2  刘大福  119.0
# 4    042010208  武汉市第四中学  6  李佳怡  128.0
# 5    042020704  武汉市第四中学  1  万茹洁  120.0
# ..         ...      ... ..  ...    ...
# 493  042021321  武汉市第四中学  9  何景轩   69.0
# 494  042021232  武汉市第四中学  4  曾治钧   79.0
# 495  042021313  武汉市第四中学  9   尹琳   82.0
# 496  042021325  武汉市第四中学  9  熊宇豪   53.0
# 497  042021040  武汉市第四中学  2  段茗馨   63.0
#
# [497 rows x 5 columns]

# %%
## 更改数据类型
df["语文成绩"] = pd.to_numeric(df["语文成绩"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 497 entries, 1 to 497
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   考号      497 non-null    object
#  1   学校      497 non-null    object
#  2   班级      497 non-null    object
#  3   学生姓名    497 non-null    object
#  4   语文成绩    496 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 23.3+ KB

# %%
df
# Out:
#             考号       学校 班级 学生姓名   语文成绩
# 1    042020722  武汉市第四中学  2  胡淑祺  120.0
# 2    042020703  武汉市第四中学  2  李长坤  117.0
# 3    042020707  武汉市第四中学  2  刘大福  119.0
# 4    042010208  武汉市第四中学  6  李佳怡  128.0
# 5    042020704  武汉市第四中学  1  万茹洁  120.0
# ..         ...      ... ..  ...    ...
# 493  042021321  武汉市第四中学  9  何景轩   69.0
# 494  042021232  武汉市第四中学  4  曾治钧   79.0
# 495  042021313  武汉市第四中学  9   尹琳   82.0
# 496  042021325  武汉市第四中学  9  熊宇豪   53.0
# 497  042021040  武汉市第四中学  2  段茗馨   63.0
#
# [497 rows x 5 columns]

# %%
### bonus?

df['语文排名'] =df["语文成绩"].rank(method = 'max')

# %%
df['语文排名'] = 497-df['语文排名']

# %%
df
# Out:
#             考号       学校 班级 学生姓名   语文成绩   语文排名
# 1    042020722  武汉市第四中学  2  胡淑祺  120.0   49.0
# 2    042020703  武汉市第四中学  2  李长坤  117.0   95.0
# 3    042020707  武汉市第四中学  2  刘大福  119.0   60.0
# 4    042010208  武汉市第四中学  6  李佳怡  128.0    3.0
# 5    042020704  武汉市第四中学  1  万茹洁  120.0   49.0
# ..         ...      ... ..  ...    ...    ...
# 493  042021321  武汉市第四中学  9  何景轩   69.0  483.0
# 494  042021232  武汉市第四中学  4  曾治钧   79.0  478.0
# 495  042021313  武汉市第四中学  9   尹琳   82.0  476.0
# 496  042021325  武汉市第四中学  9  熊宇豪   53.0  489.0
# 497  042021040  武汉市第四中学  2  段茗馨   63.0  484.0
#
# [497 rows x 6 columns]

# %%
## 编造第二次语文成绩

def function(a):
    while a > 0:
        b = a + random.randint(-15,15)
        return b
df['语文成绩2'] = df.apply(lambda x: function(x.语文成绩), axis = 1)

# %%
df
# Out:
#             考号       学校 班级 学生姓名   语文成绩   语文排名  语文成绩2
# 1    042020722  武汉市第四中学  2  胡淑祺  120.0   49.0  135.0
# 2    042020703  武汉市第四中学  2  李长坤  117.0   95.0  125.0
# 3    042020707  武汉市第四中学  2  刘大福  119.0   60.0  119.0
# 4    042010208  武汉市第四中学  6  李佳怡  128.0    3.0  133.0
# 5    042020704  武汉市第四中学  1  万茹洁  120.0   49.0  129.0
# ..         ...      ... ..  ...    ...    ...    ...
# 493  042021321  武汉市第四中学  9  何景轩   69.0  483.0   82.0
# 494  042021232  武汉市第四中学  4  曾治钧   79.0  478.0   89.0
# 495  042021313  武汉市第四中学  9   尹琳   82.0  476.0   77.0
# 496  042021325  武汉市第四中学  9  熊宇豪   53.0  489.0   46.0
# 497  042021040  武汉市第四中学  2  段茗馨   63.0  484.0   69.0
#
# [497 rows x 7 columns]

# %%
### bonus?

df['语文排名2'] =df["语文成绩2"].rank(method = 'max')

df['语文排名2'] = 497-df['语文排名2']

# %%
df
# Out:
#             考号       学校 班级 学生姓名   语文成绩   语文排名  语文成绩2  语文排名2
# 1    042020722  武汉市第四中学  2  胡淑祺  120.0   49.0  135.0    7.0
# 2    042020703  武汉市第四中学  2  李长坤  117.0   95.0  125.0   53.0
# 3    042020707  武汉市第四中学  2  刘大福  119.0   60.0  119.0  109.0
# 4    042010208  武汉市第四中学  6  李佳怡  128.0    3.0  133.0   12.0
# 5    042020704  武汉市第四中学  1  万茹洁  120.0   49.0  129.0   27.0
# ..         ...      ... ..  ...    ...    ...    ...    ...
# 493  042021321  武汉市第四中学  9  何景轩   69.0  483.0   82.0  471.0
# 494  042021232  武汉市第四中学  4  曾治钧   79.0  478.0   89.0  446.0
# 495  042021313  武汉市第四中学  9   尹琳   82.0  476.0   77.0  479.0
# 496  042021325  武汉市第四中学  9  熊宇豪   53.0  489.0   46.0  493.0
# 497  042021040  武汉市第四中学  2  段茗馨   63.0  484.0   69.0  483.0
#
# [497 rows x 8 columns]

# %%
# 进步率

# %%
df['进步名次'] = df['语文排名']-df['语文排名2']

# %%
df
# Out:
#             考号       学校 班级 学生姓名   语文成绩   语文排名  语文成绩2  语文排名2  进步名次
# 1    042020722  武汉市第四中学  2  胡淑祺  120.0   49.0  135.0    7.0  42.0
# 2    042020703  武汉市第四中学  2  李长坤  117.0   95.0  125.0   53.0  42.0
# 3    042020707  武汉市第四中学  2  刘大福  119.0   60.0  119.0  109.0 -49.0
# 4    042010208  武汉市第四中学  6  李佳怡  128.0    3.0  133.0   12.0  -9.0
# 5    042020704  武汉市第四中学  1  万茹洁  120.0   49.0  129.0   27.0  22.0
# ..         ...      ... ..  ...    ...    ...    ...    ...   ...
# 493  042021321  武汉市第四中学  9  何景轩   69.0  483.0   82.0  471.0  12.0
# 494  042021232  武汉市第四中学  4  曾治钧   79.0  478.0   89.0  446.0  32.0
# 495  042021313  武汉市第四中学  9   尹琳   82.0  476.0   77.0  479.0  -3.0
# 496  042021325  武汉市第四中学  9  熊宇豪   53.0  489.0   46.0  493.0  -4.0
# 497  042021040  武汉市第四中学  2  段茗馨   63.0  484.0   69.0  483.0   1.0
#
# [497 rows x 9 columns]

# %%
df[df['语文排名']<=10].index.tolist()   # di yi ci qian 10
# Out:
# [4, 8, 11, 13, 36, 43, 60, 188, 206, 406, 443]

# %%
df[df['语文排名2']<=10].index.tolist()   # di er ci qian 10
# Out:
# [1, 8, 18, 36, 40, 42, 49, 84, 114, 135, 209]

# %%
df1 = df.loc[df[df['语文排名']<=10].index.tolist()]

# %%
df1
# Out:
#             考号       学校 班级 学生姓名   语文成绩  语文排名  语文成绩2  语文排名2   进步名次
# 4    042010208  武汉市第四中学  6  李佳怡  128.0   3.0  133.0   12.0   -9.0
# 8    042010105  武汉市第四中学  6  周妤珂  131.0   1.0  136.0    5.0   -4.0
# 11   042020742  武汉市第四中学  1  杜枭雄  125.0   9.0  128.0   34.0  -25.0
# 13   042020838  武汉市第四中学  3   徐奇  127.0   5.0  128.0   34.0  -29.0
# 36   042020714  武汉市第四中学  2  张云鹏  127.0   5.0  137.0    1.0    4.0
# 43   042020837  武汉市第四中学  2  王桐泽  125.0   9.0  118.0  126.0 -117.0
# 60   042010136  武汉市第四中学  8  张琬童  125.0   9.0  132.0   13.0   -4.0
# 188  042010502  武汉市第四中学  6  孙金琳  128.0   3.0  127.0   40.0  -37.0
# 206  042010414  武汉市第四中学  6  吴亚婷  126.0   8.0  128.0   34.0  -26.0
# 406  042021142  武汉市第四中学  3  韩致远  127.0   5.0  126.0   49.0  -44.0
# 443  042021236  武汉市第四中学  3  秦为婧  130.0   2.0  124.0   60.0  -58.0

# %%
## mei ban nian ji qian 10 ren shu (1)
s1 = len(df1.loc[df["班级"] == '1'])
s2 = len(df1.loc[df["班级"] == '2'])
s3  = len(df1.loc[df["班级"] == '3'])
s4 = len(df1.loc[df["班级"] == '4'])
s5 = len(df1.loc[df["班级"] == '5'])
s6= len(df1.loc[df["班级"] == '6'])
s7 = len(df1.loc[df["班级"] == '7'])
s8 = len(df1.loc[df["班级"] == '8'])
s9 = len(df1.loc[df["班级"] == '9'])
s10 = len(df1.loc[df["班级"] == '10'])

# %%
## 年级前10人数  尖子生老师得分
def J(x):
    if x <= 3:
        return 5*x
    else:
        return 15

# %%
df2 = df.loc[df[df['语文排名2']<=10].index.tolist()]

# %%
df2
# Out:
#             考号       学校  班级 学生姓名   语文成绩  语文排名  语文成绩2  语文排名2  进步名次
# 1    042020722  武汉市第四中学   2  胡淑祺  120.0  49.0  135.0    7.0  42.0
# 8    042010105  武汉市第四中学   6  周妤珂  131.0   1.0  136.0    5.0  -4.0
# 18   042010109  武汉市第四中学  10  彭钰芳  123.0  18.0  137.0    1.0  17.0
# 36   042020714  武汉市第四中学   2  张云鹏  127.0   5.0  137.0    1.0   4.0
# 40   042010201  武汉市第四中学   7  李昕珏  122.0  28.0  137.0    1.0  27.0
# 42   042020730  武汉市第四中学   1  李嘉颖  124.0  12.0  135.0    7.0   5.0
# 49   042010112  武汉市第四中学   7  严琪媛  122.0  28.0  134.0    9.0  19.0
# 84   042020723  武汉市第四中学   2  朱佩文  123.0  18.0  134.0    9.0   9.0
# 114  042010335  武汉市第四中学   6  王诗佳  121.0  35.0  136.0    5.0  30.0
# 135  042010134  武汉市第四中学  10  俞欣悦  122.0  28.0  137.0    1.0  27.0
# 209  042010609  武汉市第四中学   7  秦语馨  119.0  60.0  134.0    9.0  51.0

# %%
## mei ban nian ji qian 10 ren shu (2)
S1 = len(df2.loc[df["班级"] == '1'])
S2 = len(df2.loc[df["班级"] == '2'])
S3 = len(df2.loc[df["班级"] == '3'])
S4 = len(df2.loc[df["班级"] == '4'])
S5 = len(df2.loc[df["班级"] == '5'])
S6 = len(df2.loc[df["班级"] == '6'])
S7 = len(df2.loc[df["班级"] == '7'])
S8 = len(df2.loc[df["班级"] == '8'])
S9 = len(df2.loc[df["班级"] == '9'])
S10 = len(df2.loc[df["班级"] == '10'])

# %%
# Out:
# 0

# %%
### 进行班级筛选,学生按班级分类

# %%
class1 = df.loc[df["班级"] == '1']
class2 = df.loc[df["班级"] == '2']
class3 = df.loc[df["班级"] == '3']
class4 = df.loc[df["班级"] == '4']
class5 = df.loc[df["班级"] == '5']
class6 = df.loc[df["班级"] == '6']
class7 = df.loc[df["班级"] == '7']
class8 = df.loc[df["班级"] == '8']
class9 = df.loc[df["班级"] == '9']
class10 = df.loc[df["班级"] == '10']

# %%
class1
# Out:
#             考号       学校 班级  学生姓名   语文成绩   语文排名  语文成绩2  语文排名2   进步名次
# 5    042020704  武汉市第四中学  1   万茹洁  120.0   49.0  129.0   27.0   22.0
# 11   042020742  武汉市第四中学  1   杜枭雄  125.0    9.0  128.0   34.0  -25.0
# 12   042020803  武汉市第四中学  1   徐雪瑶  118.0   75.0  121.0   98.0  -23.0
# 17   042020705  武汉市第四中学  1   万梓豪  115.0  130.0  113.0  190.0  -60.0
# 19   042020720  武汉市第四中学  1   张志远  112.0  191.0   97.0  382.0 -191.0
# 25   042020724  武汉市第四中学  1   许康哲  106.0  325.0  110.0  239.0   86.0
# 27   042020701  武汉市第四中学  1    吴昊  112.0  191.0  114.0  176.0   15.0
# 34   042020702  武汉市第四中学  1   谢宇菲  109.0  257.0  114.0  176.0   81.0
# 39   042020711  武汉市第四中学  1    唐科  111.0  211.0  119.0  109.0  102.0
# 42   042020730  武汉市第四中学  1   李嘉颖  124.0   12.0  135.0    7.0    5.0
# 44   042020740  武汉市第四中学  1    唐利  114.0  156.0  129.0   27.0  129.0
# 45   042020734  武汉市第四中学  1   何浩淼  121.0   35.0  113.0  190.0 -155.0
# 50   042020920  武汉市第四中学  1    罗安  121.0   35.0  113.0  190.0 -155.0
# ...

# %%
### min-max Normalizion
##  100*归一化

def function(a):
    while a > 0:
        d = 100*(a-min(class1['语文成绩2']))/(max(class1['语文成绩2'])-min(class1['语文成绩2']))
        return d
class1['离差分'] = class1.apply(lambda x: function(x.语文成绩2), axis = 1)
# Out:
# /home/yifan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
class1
# Out:
#             考号       学校 班级  学生姓名   语文成绩   语文排名  语文成绩2  语文排名2   进步名次    离差分
# 5    042020704  武汉市第四中学  1   万茹洁  120.0   49.0  129.0   27.0   22.0   88.0
# 11   042020742  武汉市第四中学  1   杜枭雄  125.0    9.0  128.0   34.0  -25.0   86.0
# 12   042020803  武汉市第四中学  1   徐雪瑶  118.0   75.0  121.0   98.0  -23.0   72.0
# 17   042020705  武汉市第四中学  1   万梓豪  115.0  130.0  113.0  190.0  -60.0   56.0
# 19   042020720  武汉市第四中学  1   张志远  112.0  191.0   97.0  382.0 -191.0   24.0
# 25   042020724  武汉市第四中学  1   许康哲  106.0  325.0  110.0  239.0   86.0   50.0
# 27   042020701  武汉市第四中学  1    吴昊  112.0  191.0  114.0  176.0   15.0   58.0
# 34   042020702  武汉市第四中学  1   谢宇菲  109.0  257.0  114.0  176.0   81.0   58.0
# 39   042020711  武汉市第四中学  1    唐科  111.0  211.0  119.0  109.0  102.0   68.0
# 42   042020730  武汉市第四中学  1   李嘉颖  124.0   12.0  135.0    7.0    5.0  100.0
# 44   042020740  武汉市第四中学  1    唐利  114.0  156.0  129.0   27.0  129.0   88.0
# ...

# %%
class1_cha = len(class1.loc[class1[class1['离差分']>=70].index.tolist()]) # 离差分70以上人数

# %%
print(class1_cha)
# Out:
# 12

# %%
 #  class2
def function(a):
    while a > 0:
        d = 100*(a-min(class2['语文成绩2']))/(max(class2['语文成绩2'])-min(class2['语文成绩2']))
        return d
class2['离差分'] = class2.apply(lambda x: function(x.语文成绩2), axis = 1)
# Out:
# /home/yifan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
j1 = class1['进步名次'].sum()

# %%
class2
# Out:
#             考号       学校 班级 学生姓名   语文成绩   语文排名  语文成绩2  语文排名2   进步名次         离差分
# 1    042020722  武汉市第四中学  2  胡淑祺  120.0   49.0  135.0    7.0   42.0   97.058824
# 2    042020703  武汉市第四中学  2  李长坤  117.0   95.0  125.0   53.0   42.0   82.352941
# 3    042020707  武汉市第四中学  2  刘大福  119.0   60.0  119.0  109.0  -49.0   73.529412
# 9    042020713  武汉市第四中学  2  殷昕姿  116.0  109.0  114.0  176.0  -67.0   66.176471
# 10   042020710  武汉市第四中学  2  林慧婷  118.0   75.0  123.0   70.0    5.0   79.411765
# 14   042020718  武汉市第四中学  2  张博一  120.0   49.0  113.0  190.0 -141.0   64.705882
# 16   042020728  武汉市第四中学  2   李烁  123.0   18.0  116.0  147.0 -129.0   69.117647
# 26   042020709  武汉市第四中学  2  陈湘禾  121.0   35.0  124.0   60.0  -25.0   80.882353
# 28   042020815  武汉市第四中学  2  刘欣悦  118.0   75.0  112.0  205.0 -130.0   63.235294
# 36   042020714  武汉市第四中学  2  张云鹏  127.0    5.0  137.0    1.0    4.0  100.000000
# 43   042020837  武汉市第四中学  2  王桐泽  125.0    9.0  118.0  126.0 -117.0   72.058824
# ...

# %%
j2 = class2['进步名次'].sum()

# %%
class2_cha = len(class2.loc[class2[class2['离差分']>=70].index.tolist()]) # 离差分70以上人数

# %%
class2_cha
# Out:
# 21

# %%
### class3
def function(a):
    while a > 0:
        d = 100*(a-min(class3['语文成绩2']))/(max(class3['语文成绩2'])-min(class3['语文成绩2']))
        return d
class3['离差分'] = class3.apply(lambda x: function(x.语文成绩2), axis = 1)

class3_cha = len(class3.loc[class3[class3['离差分']>=70].index.tolist()]) # 离差分70以上人数

print(class3_cha)
# Out:
# 15
# /home/yifan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
j3 = class3['进步名次'].sum()

# %%
### class4
def function(a):
    while a > 0:
        d = 100*(a-min(class4['语文成绩2']))/(max(class4['语文成绩2'])-min(class4['语文成绩2']))
        return d
class4['离差分'] = class4.apply(lambda x: function(x.语文成绩2), axis = 1)

class4_cha = len(class4.loc[class4[class4['离差分']>=70].index.tolist()]) # 离差分70以上人数

print(class4_cha)
# Out:
# 20
# /home/yifan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
j4 = class4['进步名次'].sum()

# %%
### class5
def function(a):
    while a > 0:
        d = 100*(a-min(class5['语文成绩2']))/(max(class5['语文成绩2'])-min(class5['语文成绩2']))
        return d
class5['离差分'] = class5.apply(lambda x: function(x.语文成绩2), axis = 1)

class5_cha = len(class5.loc[class5[class5['离差分']>=70].index.tolist()]) # 离差分70以上人数

print(class5_cha)
# Out:
# 16
# /home/yifan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
j5 = class5['进步名次'].sum()

# %%
### class6
def function(a):
    while a > 0:
        d = 100*(a-min(class6['语文成绩2']))/(max(class6['语文成绩2'])-min(class6['语文成绩2']))
        return d
class6['离差分'] = class6.apply(lambda x: function(x.语文成绩2), axis = 1)

class6_cha = len(class6.loc[class6[class6['离差分']>=70].index.tolist()]) # 离差分70以上人数

print(class6_cha)
# Out:
# 12
# /home/yifan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
j6 = class6['进步名次'].sum()

# %%
### class7
def function(a):
    while a > 0:
        d = 100*(a-min(class7['语文成绩2']))/(max(class7['语文成绩2'])-min(class7['语文成绩2']))
        return d
class7['离差分'] = class7.apply(lambda x: function(x.语文成绩2), axis = 1)

class7_cha = len(class7.loc[class7[class7['离差分']>=70].index.tolist()]) # 离差分70以上人数

print(class7_cha)
# Out:
# 30
# /home/yifan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
j7 = class7['进步名次'].sum()

# %%
### class8
def function(a):
    while a > 0:
        d = 100*(a-min(class8['语文成绩2']))/(max(class8['语文成绩2'])-min(class8['语文成绩2']))
        return d
class8['离差分'] = class8.apply(lambda x: function(x.语文成绩2), axis = 1)

class8_cha = len(class8.loc[class8[class8['离差分']>=70].index.tolist()]) # 离差分70以上人数

print(class8_cha)
# Out:
# 26
# /home/yifan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
j8 = class8['进步名次'].sum()

# %%
### class9
def function(a):
    while a > 0:
        d = 100*(a-min(class9['语文成绩2']))/(max(class9['语文成绩2'])-min(class9['语文成绩2']))
        return d
class9['离差分'] = class9.apply(lambda x: function(x.语文成绩2), axis = 1)

class9_cha = len(class9.loc[class9[class9['离差分']>=70].index.tolist()]) # 离差分70以上人数

print(class9_cha)
# Out:
# 20
# /home/yifan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
j9 = class9['进步名次'].sum()

# %%
### class10
def function(a):
    while a > 0:
        d = 100*(a-min(class10['语文成绩2']))/(max(class10['语文成绩2'])-min(class10['语文成绩2']))
        return d
class10['离差分'] = class10.apply(lambda x: function(x.语文成绩2), axis = 1)

class10_cha = len(class10.loc[class10[class10['离差分']>=70].index.tolist()]) # 离差分70以上人数

print(class10_cha)
# Out:
# 29
# /home/yifan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
j10 = class10['进步名次'].sum()

# %%
list_l = [class1_cha,class2_cha,class3_cha,class4_cha,class5_cha,class6_cha,class7_cha,class8_cha,class9_cha,class10_cha,]

# %%
list_l
# Out:
# [12, 21, 15, 20, 16, 12, 30, 26, 20, 29]

# %%
M = df["语文成绩"].mean()
Me = df["语文成绩2"].mean()
## 年级语文成绩平均分

# %%
### 计算各班平均分
M1 = class1["语文成绩"].mean()
M2 = class2["语文成绩"].mean()
M3 = class3["语文成绩"].mean()
M4 = class4["语文成绩"].mean()
M5 = class5["语文成绩"].mean()
M6 = class6["语文成绩"].mean()
M7 = class7["语文成绩"].mean()
M8 = class8["语文成绩"].mean()
M9 = class9["语文成绩"].mean()
M10 = class10["语文成绩"].mean()

### 计算各班平均分2
Me1 = class1["语文成绩2"].mean()
Me2 = class2["语文成绩2"].mean()
Me3 = class3["语文成绩2"].mean()
Me4 = class4["语文成绩2"].mean()
Me5 = class5["语文成绩2"].mean()
Me6 = class6["语文成绩2"].mean()
Me7 = class7["语文成绩2"].mean()
Me8 = class8["语文成绩2"].mean()
Me9 = class9["语文成绩2"].mean()
Me10 = class10["语文成绩2"].mean()

# %%
print(M1,M2,M3,M4,M5,M6,M7,M8,M9,M10,M)
# Out:
# 111.44444444444444 112.44444444444444 110.64285714285714 104.75471698113208 109.81818181818181 112.92857142857143 101.21818181818182 104.37254901960785 100.36842105263158 109.69642857142857 107.83266129032258

# %%
print(Me1,Me2,Me3,Me4,Me5,Me6,Me7,Me8,Me9,Me10,Me)
# Out:
# 110.77777777777777 114.22222222222223 107.78571428571429 103.90566037735849 108.32727272727273 115.10714285714286 102.45454545454545 101.90196078431373 100.21052631578948 109.23214285714286 107.5

# %%
###  假定第1次211线109  一本线100   二本线91  ###
###  假定第2次211线107  一本线98   二本线89  ###
###  计算1-10班两次考试上线人数 ###

# %%
 # class1 ## 1次
n1 = len(class1)  # class1 学生人数
class1_2ben_1 = len(class1.loc[class1[class1['语文成绩']>=91].index.tolist()])  #二本上线人数
class1_1ben_1 = len(class1.loc[class1[class1['语文成绩']>=100].index.tolist()])  #一本上线人数
class1_211_1 = len(class1.loc[class1[class1['语文成绩']>=109].index.tolist()])  #211上线人数

 # class1 ## 2次
class1_2ben_2 = len(class1.loc[class1[class1['语文成绩2']>=89].index.tolist()])  #二本上线人数
class1_1ben_2 = len(class1.loc[class1[class1['语文成绩2']>=98].index.tolist()])  #一本上线人数
class1_211_2 = len(class1.loc[class1[class1['语文成绩2']>=107].index.tolist()])  #211上线人数

# %%
 # class2

class2_2ben_1 = len(class2.loc[class2[class2['语文成绩']>=91].index.tolist()] ) #二本上线人数


class2_1ben_1 = len(class2.loc[class2[class2['语文成绩']>=100].index.tolist()])  #一本上线人数
class2_211_1 =len( class2.loc[class2[class2['语文成绩']>=109].index.tolist()] ) #211上线人数

# class2 ## 2次
class2_2ben_2 = len(class2.loc[class2[class2['语文成绩2']>=89].index.tolist()])  #二本上线人数
class2_1ben_2 = len(class2.loc[class2[class2['语文成绩2']>=98].index.tolist()] ) #一本上线人数
class2_211_2 = len(class2.loc[class2[class2['语文成绩2']>=107].index.tolist()] ) #211上线人数

# %%
 # class3

class3_2ben_1 =len( class3.loc[class3[class3['语文成绩']>=91].index.tolist()])  #二本上线人数
class3_1ben_1 = len(class3.loc[class3[class3['语文成绩']>=100].index.tolist()])  #一本上线人数
class3_211_1 = len( class3.loc[class3[class3['语文成绩']>=109].index.tolist()] ) #211上线人数
# class3 ## 2次

class3_2ben_2 =len( class3.loc[class3[class3['语文成绩2']>=89].index.tolist()] ) #二本上线人数
class3_1ben_2 = len(class3.loc[class3[class3['语文成绩2']>=98].index.tolist()] ) #一本上线人数
class3_211_2 =  len(class3.loc[class3[class3['语文成绩2']>=107].index.tolist()] ) #211上线人数

# %%
 # class4

class4_2ben_1 =len( class4.loc[class4[class4['语文成绩']>=91].index.tolist()] ) #二本上线人数
class4_1ben_1 = len(class4.loc[class4[class4['语文成绩']>=100].index.tolist()] ) #一本上线人数
class4_211_1 = len( class4.loc[class4[class4['语文成绩']>=109].index.tolist()] ) #211上线人数

# class4 ## 2次

class4_2ben_2 = len(class4.loc[class4[class4['语文成绩2']>=89].index.tolist()])  #二本上线人数
class4_1ben_2 = len(class4.loc[class4[class4['语文成绩2']>=98].index.tolist()] ) #一本上线人数
class4_211_2 =  len(class4.loc[class4[class4['语文成绩2']>=107].index.tolist()] ) #211上线人数

# %%
 # class5

class5_2ben_1 =len( class5.loc[class5[class5['语文成绩']>=91].index.tolist()] ) #二本上线人数
class5_1ben_1 = len(class5.loc[class5[class5['语文成绩']>=100].index.tolist()] ) #一本上线人数
class5_211_1 =  len(class5.loc[class5[class5['语文成绩']>=109].index.tolist()] ) #211上线人数

# class5 ## 2次
class5_2ben_2 = len(class5.loc[class5[class5['语文成绩2']>=89].index.tolist()] ) #二本上线人数
class5_1ben_2 = len(class5.loc[class5[class5['语文成绩2']>=98].index.tolist()] ) #一本上线人数
class5_211_2 = len( class5.loc[class5[class5['语文成绩2']>=107].index.tolist()])  #211上线人数

# %%
# class6

class6_2ben_1 =len( class6.loc[class6[class6['语文成绩']>=91].index.tolist()]  )#二本上线人数
class6_1ben_1 = len(class6.loc[class6[class6['语文成绩']>=100].index.tolist()] ) #一本上线人数
class6_211_1 =  len(class6.loc[class6[class6['语文成绩']>=109].index.tolist()] ) #211上线人数

# class6 ## 2次

class6_2ben_2 =len( class6.loc[class6[class6['语文成绩2']>=89].index.tolist()]  )#二本上线人数
class6_1ben_2 = len(class6.loc[class6[class6['语文成绩2']>=98].index.tolist()] ) #一本上线人数
class6_211_2 =  len(class6.loc[class6[class6['语文成绩2']>=107].index.tolist()] ) #211上线人数

# %%
# class7

class7_2ben_1 = len(class7.loc[class7[class7['语文成绩']>=91].index.tolist()]  )#二本上线人数
class7_1ben_1 = len(class7.loc[class7[class7['语文成绩']>=100].index.tolist()] ) #一本上线人数
class7_211_1 =  len(class7.loc[class7[class7['语文成绩']>=109].index.tolist()] ) #211上线人数

# class7 ## 2次
class7_2ben_2 = len(class7.loc[class7[class7['语文成绩2']>=89].index.tolist()]  )#二本上线人数
class7_1ben_2 = len(class7.loc[class7[class7['语文成绩2']>=98].index.tolist()]  )#一本上线人数
class7_211_2 =  len(class7.loc[class7[class7['语文成绩2']>=107].index.tolist()] ) #211上线人数

# %%
# class8

class8_2ben_1 =len( class8.loc[class8[class8['语文成绩']>=91].index.tolist()] ) #二本上线人数
class8_1ben_1 =len( class8.loc[class8[class8['语文成绩']>=100].index.tolist()] ) #一本上线人数
class8_211_1 =  len(class8.loc[class8[class8['语文成绩']>=109].index.tolist()] ) #211上线人数

# class8 ## 2次
class8_2ben_2 = len(class8.loc[class8[class8['语文成绩2']>=89].index.tolist()]  )#二本上线人数
class8_1ben_2 = len(class8.loc[class8[class8['语文成绩2']>=98].index.tolist()]  )#一本上线人数
class8_211_2 =  len(class8.loc[class8[class8['语文成绩2']>=107].index.tolist()] ) #211上线人数

# %%
# class9

class9_2ben_1 = len(class9.loc[class9[class9['语文成绩']>=91].index.tolist()] ) #二本上线人数
class9_1ben_1 = len(class9.loc[class9[class9['语文成绩']>=100].index.tolist()] ) #一本上线人数
class9_211_1 =  len(class9.loc[class9[class9['语文成绩']>=109].index.tolist()] ) #211上线人数


# class9 ## 2次
class9_2ben_2 = len(class9.loc[class9[class9['语文成绩2']>=89].index.tolist()] ) #二本上线人数
class9_1ben_2 = len(class9.loc[class9[class9['语文成绩2']>=98].index.tolist()] ) #一本上线人数
class9_211_2 =  len(class9.loc[class9[class9['语文成绩2']>=107].index.tolist()] ) #211上线人数

# %%
 # class10

class10_2ben_1 =len( class10.loc[class10[class10['语文成绩']>=91].index.tolist()] ) #二本上线人数
class10_1ben_1 = len(class10.loc[class10[class10['语文成绩']>=100].index.tolist()] ) #一本上线人数
class10_211_1 = len(class10.loc[class10[class10['语文成绩']>=109].index.tolist()] ) #211上线人数

# class10 ## 2次
class10_2ben_2 = len(class10.loc[class10[class10['语文成绩2']>=89].index.tolist()] ) #二本上线人数
class10_1ben_2 =len( class10.loc[class10[class10['语文成绩2']>=98].index.tolist()] ) #一本上线人数
class10_211_2 = len(class10.loc[class10[class10['语文成绩2']>=107].index.tolist()]  )#211上线人数

# %%
'离差值70以上人数'
# Out:
# '离差值70以上人数'

# %%
DFf = pd.DataFrame.from_dict(
    {'1班': pd.Series([class1_2ben_1,class1_2ben_2,class1_1ben_1,class1_1ben_2,class1_211_1,class1_211_2,M1,Me1,j1,s1,S1,class1_cha ],index = ['上次二本上线','本次二本上线','上次一本上线','本次一本上线','上次211上线','本次211上线','上次平均分','本次平均分','班级总进步名次','上次年级前10人数','本次年级前10人数','离差值70以上人数']),
     '2班': pd.Series([class2_2ben_1,class2_2ben_2,class2_1ben_1,class2_1ben_2,class2_211_1,class2_211_2,M2,Me2,j2,s2,S2,class2_cha],index = ['上次二本上线','本次二本上线','上次一本上线','本次一本上线','上次211上线','本次211上线','上次平均分','本次平均分','班级总进步名次','上次年级前10人数','本次年级前10人数','离差值70以上人数']),
     '3班': pd.Series([class3_2ben_1,class3_2ben_2,class3_1ben_1,class3_1ben_2,class3_211_1,class3_211_2,M3,Me3,j3,s3,S3,class3_cha],index = ['上次二本上线','本次二本上线','上次一本上线','本次一本上线','上次211上线','本次211上线','上次平均分','本次平均分','班级总进步名次','上次年级前10人数','本次年级前10人数','离差值70以上人数']),
     '4班': pd.Series([class4_2ben_1,class4_2ben_2,class4_1ben_1,class4_1ben_2,class4_211_1,class4_211_2,M4,Me4,j4,s4,S4,class4_cha],index = ['上次二本上线','本次二本上线','上次一本上线','本次一本上线','上次211上线','本次211上线','上次平均分','本次平均分','班级总进步名次','上次年级前10人数','本次年级前10人数','离差值70以上人数']),
     '5班': pd.Series([class5_2ben_1,class5_2ben_2,class5_1ben_1,class5_1ben_2,class5_211_1,class5_211_2,M5,Me5,j5,s5,S5,class5_cha],index = ['上次二本上线','本次二本上线','上次一本上线','本次一本上线','上次211上线','本次211上线','上次平均分','本次平均分','班级总进步名次','上次年级前10人数','本次年级前10人数','离差值70以上人数']),
     '6班': pd.Series([class6_2ben_1,class6_2ben_2,class6_1ben_1,class6_1ben_2,class6_211_1,class6_211_2,M6,Me6,j6,s6,S6,class6_cha],index = ['上次二本上线','本次二本上线','上次一本上线','本次一本上线','上次211上线','本次211上线','上次平均分','本次平均分','班级总进步名次','上次年级前10人数','本次年级前10人数','离差值70以上人数']),
     '7班': pd.Series([class7_2ben_1,class7_2ben_2,class7_1ben_1,class7_1ben_2,class7_211_1,class7_211_2,M7,Me7,j7,s7,S7,class7_cha],index = ['上次二本上线','本次二本上线','上次一本上线','本次一本上线','上次211上线','本次211上线','上次平均分','本次平均分','班级总进步名次','上次年级前10人数','本次年级前10人数','离差值70以上人数']),
     '8班': pd.Series([class8_2ben_1,class8_2ben_2,class8_1ben_1,class8_1ben_2,class8_211_1,class8_211_2,M8,Me8,j8,s8,S8,class8_cha],index = ['上次二本上线','本次二本上线','上次一本上线','本次一本上线','上次211上线','本次211上线','上次平均分','本次平均分','班级总进步名次','上次年级前10人数','本次年级前10人数','离差值70以上人数']),
     '9班': pd.Series([class9_2ben_1,class9_2ben_2,class9_1ben_1,class9_1ben_2,class9_211_1,class9_211_2,M9,Me9,j9,s9,S9,class9_cha],index = ['上次二本上线','本次二本上线','上次一本上线','本次一本上线','上次211上线','本次211上线','上次平均分','本次平均分','班级总进步名次','上次年级前10人数','本次年级前10人数','离差值70以上人数']),
     '10班': pd.Series([class10_2ben_1,class10_2ben_2,class10_1ben_1,class10_1ben_2,class10_211_1,class10_211_2,M10,Me10,j10,s10,S10,class10_cha],index = ['上次二本上线','本次二本上线','上次一本上线','本次一本上线','上次211上线','本次211上线','上次平均分','本次平均分','班级总进步名次','上次年级前10人数','本次年级前10人数','离差值70以上人数'])
    })

# %%
DFf
# Out:
#                    1班          2班          3班           4班          5班  \
# 上次二本上线      45.000000   43.000000   42.000000    49.000000   54.000000
# 本次二本上线      43.000000   43.000000   36.000000    48.000000   52.000000
# 上次一本上线      41.000000   40.000000   38.000000    37.000000   48.000000
# 本次一本上线      35.000000   40.000000   30.000000    37.000000   42.000000
# 上次211上线     30.000000   35.000000   26.000000    18.000000   35.000000
# 本次211上线     29.000000   34.000000   25.000000    24.000000   32.000000
# 上次平均分      111.444444  112.444444  110.642857   104.754717  109.818182
# 本次平均分      110.777778  114.222222  107.785714   103.905660  108.327273
# 班级总进步名次   -659.000000 -513.000000 -824.000000  1135.000000 -883.000000
# 上次年级前10人数    1.000000    2.000000    3.000000     0.000000    0.000000
# 本次年级前10人数    1.000000    3.000000    0.000000     0.000000    0.000000
# 离差值70以上人数   12.000000   21.000000   15.000000    20.000000   16.000000
#
# ...
